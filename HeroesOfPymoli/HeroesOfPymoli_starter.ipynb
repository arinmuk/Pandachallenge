# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
purchase_grpby=purchase_data.groupby(["SN"])
t_players= purchase_grpby['SN'].unique().count()
total_players = pd.DataFrame([{"Total Players":t_players}])
total_players
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_items = purchase_data.groupby(["Item ID"])
unique_count= unique_items["Item ID"].unique().count()
avg_price = purchase_data["Price"].mean()

purchases = purchase_data["Purchase ID"].count()
revenue = purchase_data["Price"].sum()
pur_analysis = pd.DataFrame([
    {"Number of Unique Items":unique_count,
    "Average Price":avg_price,
    "Number of Purchases":purchases,
    "Total Revenue":revenue},
])

pur_analysis["Average Price"]=pur_analysis["Average Price"].map("${:.2f}".format)
pur_analysis["Total Revenue"]=pur_analysis["Total Revenue"].map("${:,.2f}".format)
purchase_analysis= pur_analysis[["Number of Unique Items","Average Price","Number of Purchases","Total Revenue"]]
purchase_analysis
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     183         $3.05                  780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
vcounts=purchase_data[["SN","Gender"]]
vcounts["Gender"].value_counts()
male_df = vcounts.loc[vcounts["Gender"] == "Male", :]
female_df=vcounts.loc[vcounts["Gender"] == "Female", :]
other_df=vcounts.loc[vcounts["Gender"] == "Other / Non-Disclosed", :]
male_count=len(male_df.groupby(["SN","Gender"])["SN"].count())
female_count=len(female_df.groupby(["SN","Gender"])["SN"].count())
other_count=len(other_df.groupby(["SN","Gender"])["SN"].count())
p_male=(male_count/total_unique_SN)*100
p_female=(female_count/total_unique_SN)*100
p_other=(other_count/total_unique_SN)*100
total_unique_SN=male_count+female_count+other_count
summary={"":["Male","Female","Other / Non-Disclosed"],
         "Total Count":[male_count,female_count,other_count],
         "Percentage of Players":[p_male,p_female,p_other]
        }
results_fr=pd.DataFrame(summary).round(2)
results_fr.head()
# Out:
#                           Total Count  Percentage of Players
# 0                   Male          484                  84.03
# 1                 Female           81                  14.06
# 2  Other / Non-Disclosed           11                   1.91

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_df=purchase_data.groupby(["Gender"],as_index=False)["Purchase ID"].count()
purchase_df=purchase_df.rename(columns={"Purchase ID":"Purchase Count"})
avg_df=purchase_data.groupby(["Gender"],as_index=False)["Price"].mean()

avg_df["Price"]=avg_df["Price"].map("${:.2f}".format)
avg_df=avg_df.rename(columns={"Price":"Average Purchase Price"})

tot_pur_df=purchase_data.groupby(["Gender"],as_index=False)["Price"].sum()
tot_pur_df["Price"]=tot_pur_df["Price"].map("${:,.2f}".format)
tot_pur_df=tot_pur_df.rename(columns={"Price":"Total Purchase Value"})

avg_pur_per_df= purchase_data.groupby(["SN","Gender"],as_index=False)["Price"].sum()
sum_avg_df=avg_pur_per_df.groupby("Gender",as_index=False)["Price"].mean()
sum_avg_df["Price"]=sum_avg_df["Price"].map("${:.2f}".format)
sum_avg_df=sum_avg_df.rename(columns={"Price":"Avg Total Purchase per Person"})
sum_avg_df.head()
new_f1 = pd.concat([purchase_df,avg_df["Average Purchase Price"],tot_pur_df["Total Purchase Value"],sum_avg_df["Avg Total Purchase per Person"]],axis=1)
summary_df = new_f1.round(2)
#new_f1.head()
summary_df.head()
# Out:
#                   Gender  Purchase Count Average Purchase Price  \
# 0                 Female             113                  $3.20
# 1                   Male             652                  $3.02
# 2  Other / Non-Disclosed              15                  $3.35
#
#   Total Purchase Value Avg Total Purchase per Person
# 0              $361.94                         $4.47
# 1            $1,967.64                         $4.07
# 2               $50.19                         $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
#work_df=purchase_data.groupby(["SN","Age"],as_index=False)
#work_df.head()

purchase_data.count()
work_drp_dup=purchase_data
work_pur=work_drp_dup.drop_duplicates(subset ="SN", keep = "first")
#del work_pur["Player Age Summary"]
tot_player=work_pur["Age"].count()
bins = [0, 9, 14, 19, 24, 29,34,39,100]

# Create the names for the four bins


group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39","40+"]
work_pur["Player Age Summary"] = pd.cut(purchase_data["Age"], bins, labels=group_names)
work_pur_grp=work_pur.groupby(["Player Age Summary"],as_index=False)
#work_pur_grp.count()
summary_inter= work_pur_grp.count()
summary_result=summary_inter[["Player Age Summary","SN"]]
summary_result=summary_result.rename(columns={"SN":"Total Count"})
summary_result["Percentage of Players"]=round((summary_result["Total Count"]/tot_player)*100,2)
#print( summary_result.to_string(index=False))
summary_result.head(12)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#   Player Age Summary  Total Count  Percentage of Players
# 0                <10           17                   2.95
# 1              10-14           22                   3.82
# 2              15-19          107                  18.58
# 3              20-24          258                  44.79
# 4              25-29           77                  13.37
# 5              30-34           52                   9.03
# 6              35-39           31                   5.38
# 7                40+           12                   2.08

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
work_pur=purchase_data

tot_player=work_pur["Age"].count()
bins = [0, 9, 14, 19, 24, 29,34,39,100]



group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39","40+"]
work_pur["Player Age Summary"] = pd.cut(purchase_data["Age"], bins, labels=group_names)
work_pur_grp=work_pur.groupby(["Player Age Summary"],as_index=False)["Purchase ID"].count()
work_pur_grp=work_pur_grp.rename(columns={"Purchase ID":"Purchase Count"})
work_pur_grp_avg=work_pur.groupby(["Player Age Summary"],as_index=False)["Price"].mean()
work_pur_grp_avg=work_pur_grp_avg.rename(columns={"Price":"Average Purchase Price"})

work_pur_grp_sum=work_pur.groupby(["Player Age Summary"],as_index=False)["Price"].sum()
work_pur_grp_sum.convert_objects(convert_numeric=True)
summary_result.convert_objects(convert_numeric=True)

work_pur_grp_sum=work_pur_grp_sum.rename(columns={"Price":"Total Purchase Value"})


new_f1 = pd.concat([work_pur_grp,work_pur_grp_avg["Average Purchase Price"],work_pur_grp_sum["Total Purchase Value"],(work_pur_grp_sum["Total Purchase Value"]/summary_result["Total Count"])],axis=1)
new_f1["Average Purchase Price"]=new_f1["Average Purchase Price"].map("${:.2f}".format)
new_f1["Total Purchase Value"]=new_f1["Total Purchase Value"].map("${:,.2f}".format)

new_f1=new_f1.rename(columns={0:"Avg Total Purchase Per Person"})
new_f1["Avg Total Purchase Per Person"]=new_f1["Avg Total Purchase Per Person"].map("${:,.2f}".format)
new_f1.sort_values("Player Age Summary")
#new_f1.head(18)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   Player Age Summary  Purchase Count Average Purchase Price  \
# 0                <10              23                  $3.35
# 1              10-14              28                  $2.96
# 2              15-19             136                  $3.04
# 3              20-24             365                  $3.05
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
top_spend=purchase_data
top_spend_grp=top_spend.groupby(["SN"],as_index=False)["Purchase ID"].count()
top_spend_grp_avg= top_spend.groupby(["SN"],as_index=False)["Price"].mean()
top_spend_grp_sum= top_spend.groupby(["SN"],as_index=False)["Price"].sum()

top_spend_grp_avg=top_spend_grp_avg.rename(columns={"Price":"Average Purchase Price"})
top_spend_grp_sum=top_spend_grp_sum.rename(columns={"Price":"Total Purchase Value"})
new_f2 = pd.concat([top_spend_grp,top_spend_grp_avg["Average Purchase Price"],top_spend_grp_sum["Total Purchase Value"]],axis=1)
new_f3=new_f2.sort_values("Total Purchase Value",ascending=False)
#new_f3.reset_index(drop=True)
new_f3["Total Purchase Value"]=new_f3["Total Purchase Value"].map("${:,.2f}".format)
new_f3["Average Purchase Price"]=new_f3["Average Purchase Price"].map("${:,.2f}".format)

new_f3.head()
#top_spend_grp_sum.head(112)
# Out:
#               SN  Purchase ID Average Purchase Price Total Purchase Value
# 360    Lisosia93            5                  $3.79               $18.96
# 246  Idastidru52            4                  $3.86               $15.45
# 106   Chamjask73            3                  $4.61               $13.83
# 275       Iral74            4                  $3.40               $13.62
# 281  Iskadarya95            3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 145     Fiery Glass Crusader                                      9
# 108     Extraction, Quickblade Of Trembling Hands                 9
# 82      Nirvana                                                   9
# 19      Pursuit, Cudgel of Necromancy                             8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
# 82      Nirvana                                           $4.90
# 19      Pursuit, Cudgel of Necromancy                     $1.02
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 92      Final Critic                                              8
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 92      Final Critic                                      $4.88
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...
